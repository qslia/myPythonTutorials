# %%
type(True)
type(False)
type(3.14)
type(3)
type(3.0)
# Out:
# float

# %%
int(3.9)
# Out:
# 3

# %%
float(3)
# Out:
# 3.0

# %%
2 + 3
# Out:
# 5

# %%
4 % 3
# Out:
# 1

# %%
2 % 3
# Out:
# 2

# %%
2 / 3
# Out:
# 0.6666666666666666

# %%
2 ** 3
# Out:
# 8

# %%
PI = 3.14159
PI
# Out:
# 3.14159

# %%
PI = 3.14159
radius = 10
area = PI * radius ** 2
area
# Out:
# 314.159

# %%
radius = radius + 1
radius
# Out:
# 11

# %%
radius += 1
radius
# Out:
# 12

# %%
hi = "hello there"
hi
# Out:
# 'hello there'

# %%
type(hi)
# Out:
# str

# %%
# This is a comment

# %%
hi = "hello there"  # string
hi
# Out:
# 'hello there'

# %%
hi = 'hello there'  
hi
# Out:
# 'hello there'

# %%
print(hi)
# Out:
# hello there

# %%
name = "ana"
greet = hi + name
greet
# Out:
# 'hello thereana'

# %%
name = "ana"
greet = hi + " " + name
greet
# Out:
# 'hello there ana'

# %%
name = "ana"
greet = hi + name
greet

name = "ana"
greet = hi + " " + name
greet
# Out:
# 'hello there ana'

# %%
name = "ana"
greet = hi + name
print(greet)
greet = hi + " " + name
print(greet)
# Out:
# hello thereana
# hello there ana

# %%
f"{hi} {name}"
# Out:
# 'hello there ana'

# %%
print(f"{hi} {name}")
# Out:
# hello there ana

# %%
silly = hi + " " + name * 3
silly
# Out:
# 'hello there anaanaana'

# %%
x = 1234
x_str = str(x)
x_str
# Out:
# '1234'

# %%
type(x_str)
# Out:
# str

# %%
text = input("Enter something: ")
text
# Out:
# '123232'

# %%
print(text)
# Out:
# 123232

# %%
type(text)
# Out:
# str

# %%
num = int(input("Enter a number: "))
num
# Out:
# 1234

# %%
type(num)
# Out:
# int

# %%
int('1234')
# Out:
# 1234

# %%
pset_time = 15
sleep_time = 8
sleep_time > pset_time
# Out:
# False

# %%
derive = True
drink = False

# %%
derive and drink
# Out:
# False

# %%
derive or drink
# Out:
# True

# %%
both = derive and drink
both
# Out:
# False

# %%
x = 3.1
y = 3.3
print(x == y)
print(x != y)
print(x < y)
print(x > y)
# Out:
# False
# True
# True
# False

# %%
x = 3.1
y = 3.3

if x == y:
    print("x and y are equal")
elif x < y:
    print("x is less than y")
else:
    print("x is greater than y")
# Out:
# x is less than y

# %%
x = 3
y = 3

if x == y:
    print("x and y are equal")
    if y != 0:
        print("y is not zero, x / y is", x / y)
elif x < y:
    print("x is less than y")
else:
    print("x is greater than y")
# Out:
# x and y are equal
# y is not zero, x / y is 1.0

# %%
x = 3
y = 3

if x = y:  # what if x = y here, get a SyntaxError
    print("x and y are equal")
    if y != 0:
        print("y is not zero, x / y is", x / y)
elif x < y:
    print("x is less than y")
else:
    print("x is greater than y")
# Out:
#   Cell In[69], line 4
#     if x = y:  # what if x = y here, get a SyntaxError
#        ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
